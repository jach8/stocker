# %%
import pickle
import pandas as pd 
import sqlite3 
import os 
import json 
import datetime as dt 
import numpy as np 
from bin.main import init, get_path
# init()

# %%
from main import Pipeline as Manager
m = Manager()
# Out:
# Options db Connected: 2024-11-05 15:50:49.531704
# Prices Connected: 2024-11-05 15:50:49.533029

# %%
m.performance.show_performance()
# Out:
# --------------------------------------------------------- Winners ---------------------------------------------------------
#               Daily             Weekly            Monthly         Quarterly  \
# 0  ($rddt, 11.034%)   ($rddt, 48.795%)    ($rddt, 1.475%)  ($rddt, 83.647%)
# 1   ($vktx, 0.253%)  ($vktx, -18.877%)  ($vktx, -12.738%)  ($vktx, -0.016%)
#
#               Annual                YTD
# 0  ($rddt, 163.174%)  ($rddt, 163.174%)
# 1   ($vktx, -8.986%)   ($vktx, -8.986%)
# --------------------------------------------------------- Losers ---------------------------------------------------------
#               Daily             Weekly            Monthly         Quarterly  \
# 0   ($vktx, 0.253%)  ($vktx, -18.877%)  ($vktx, -12.738%)  ($vktx, -0.016%)
# 1  ($rddt, 11.034%)   ($rddt, 48.795%)    ($rddt, 1.475%)  ($rddt, 83.647%)
#
#               Annual                YTD
# 0   ($vktx, -8.986%)   ($vktx, -8.986%)
# 1  ($rddt, 163.174%)  ($rddt, 163.174%)

# %%
m.dxp.run('rddt')
# Out:
#            stock  type  strike  sd          gatherdate       contractsymbol  \
# expiry
# 2027-01-15  RDDT   Put   100.0   2 2024-11-05 15:00:59  RDDT270115P00100000
# 2024-12-20  RDDT   Put   100.0   2 2024-11-05 15:00:59  RDDT241220P00100000
# 2024-12-13  RDDT   Put   100.0   2 2024-11-05 15:00:59  RDDT241213P00100000
# 2025-04-17  RDDT   Put   100.0   2 2024-11-05 15:00:59  RDDT250417P00100000
# 2026-01-16  RDDT   Put   100.0   2 2024-11-05 15:00:59  RDDT260116P00100000
# 2025-01-17  RDDT   Put   100.0   2 2024-11-05 15:00:59  RDDT250117P00100000
# 2024-12-06  RDDT   Put   101.0   2 2024-11-05 15:00:59  RDDT241206P00101000
# 2024-11-29  RDDT   Put   102.0   2 2024-11-05 15:00:59  RDDT241129P00102000
# 2024-11-15  RDDT   Put   102.0   2 2024-11-05 15:00:59  RDDT241115P00102000
# 2024-11-22  RDDT   Put   102.0   2 2024-11-05 15:00:59  RDDT241122P00102000
# 2024-11-08  RDDT   Put   102.0   2 2024-11-05 15:00:59  RDDT241108P00102000
# ...
